# %%
import pandas as pd

# %%
df = pd.read_csv("../../data/개인CB_씬파일러.csv")
print(df.head())
# Out:
#      STDT                                                 ID  GENDER  \
# 0  201912  83702E5EC3A4D8239C9D3B12F077B15BD09E8BAC4E0097...       2
# 1  201912  0A741C7058923B361931C2CD28158B6DEF991C41711464...       2
# 2  201912  351C2BCF3929F21BA0ADCE54A8C7F0D385F70856C4FE60...       2
# 3  201912  3EE225A1C2DCEFD4EE438FB4B0545900F2CF5FCDF22054...       1
# 4  201912  076C20C1C93707CC1B7E4F2F32727F434DAF0A4F3B5B25...       1
#
#    AGE_BAND  C1Z001373  C1M2B4W03  C1M2B5W03  C1Z001386  C1M210000  C1M210001  \
# 0         2       1225          0          0      -7560          0          0
# 1         6          0          0          0          0          0          0
# 2         7          0          0          0          0          0          0
# 3         2      -1413          0          0      -3521          0          0
# 4         6      -1624          0          0     -19903          0          0
#
#    ...  AP0910001  AP0910002  AS120G001  SCORE  SCORE_6M  PERF1  PERF2  PERF3  \
# ...

# %%
print(df.tail(10))
# Out:
#            STDT                                                 ID  GENDER  \
# 3254220  202212  B361B3FB45987B10946322E4C80DDBDB7E898390E87E82...       1
# 3254221  202212  6AF8C40DEC5FDD2CFB8A3426584F31DE44C11EB69B0309...       2
# 3254222  202212  A0449E86447D3657DEE18D39196D38DBA66CA6505F124A...       2
# 3254223  202212  FE3E9ED29ABB8094A409AC42E1370A2F0D4F4062855B19...       2
# 3254224  202212  072BDB960C99E99F536FBC1650A1AE133F7054AE8239B3...       2
# 3254225  202212  8E2F1360DB361E8839BF18BC0B9BCA6D4EAB9D3DC8EFA7...       1
# 3254226  202212  E800837E1D6AC98752986BD302C68CC5587554E5AB45DD...       2
# 3254227  202212  E9EE11DE8C2BDBE5B084F8B28D0A138390F61E1386B63F...       1
# 3254228  202212  00D70562D58AE094CC2C13658939865CA5EEFD27F29A81...       2
# 3254229  202212  97EA2D0E7CACD18B89A01C676435C07259242B6EA3A48E...       1
#
#          AGE_BAND  C1Z001373  C1M2B4W03  C1M2B5W03  C1Z001386  C1M210000  \
# ...
